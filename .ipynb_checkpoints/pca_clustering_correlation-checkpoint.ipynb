# %%
import pandas as pd
df_main = pd.read_csv("crypto_30_365.csv", index_col = 0 )
df_main.head()
# Out:
#             2024-02-27    2024-02-28    2024-02-29    2024-03-01  \
# Ticker
# ADA-USD       0.624216      0.631059      0.655646      0.719081
# AVAX-USD     39.268646     40.294788     40.935387     42.855328
# BCH-USD     292.519379    296.793793    298.562378    316.125031
# BNB-USD     394.995636    415.771606    399.778717    407.810760
# BTC-USD   57085.371094  62504.789062  61198.382812  62440.632812
#
#             2024-03-02    2024-03-03    2024-03-04    2024-03-05  \
# Ticker
# ADA-USD       0.740928      0.728238      0.771294      0.693490
# AVAX-USD     44.333908     42.604858     43.088238     39.500137
# BCH-USD     500.806061    469.362793    470.423157    401.490845
# BNB-USD     410.985870    414.381073    419.035431    394.661743
# BTC-USD   62029.847656  63167.371094  68330.414062  63801.199219
#
#             2024-03-06    2024-03-07  ...    2025-02-16    2025-02-17  \
# Ticker                                ...
# ADA-USD       0.733821      0.744742  ...      0.772005      0.808025
# AVAX-USD     41.514336     43.290005  ...     24.837257     25.028814
# BCH-USD     415.128448    432.400635  ...    326.468292    323.638428
# BNB-USD     429.011963    475.290649  ...    674.100830    667.229065
# BTC-USD   66106.804688  66925.484375  ...  96175.031250  95773.382812
#
#             2025-02-18    2025-02-19    2025-02-20    2025-02-21  \
# Ticker
# ADA-USD       0.752363      0.772943      0.804474      0.761371
# AVAX-USD     23.488274     23.727959     25.149733     24.519165
# BCH-USD     315.836853    322.589844    326.008942    313.649139
# BNB-USD     647.443359    653.514709    657.200989    646.899536
# BTC-USD   95539.546875  96635.609375  98333.937500  96125.546875
#
#             2025-02-22    2025-02-23    2025-02-24    2025-02-26
# Ticker
# ADA-USD       0.774452      0.770041      0.682202      0.676810
# AVAX-USD     25.816496     24.885553     21.880913     21.708748
# BCH-USD     320.994049    327.884247    291.614929    290.690613
# BNB-USD     668.574768    657.903687    613.963013    625.598450
# BTC-USD   96577.757812  96273.921875  91418.171875  88168.421875
#
# [5 rows x 365 columns]

# %%
df_main.isna().sum().sum()
# Out:
# 266

# %%
df_cleaned = df_main.fillna(method = "ffill", axis = 1).fillna(method="bfill", axis = 1)
df_cleaned.head()
# Out:
# C:\Users\Solent\AppData\Local\Temp\ipykernel_20596\522373192.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_cleaned = df_main.fillna(method = "ffill", axis = 1).fillna(method="bfill", axis = 1)
#             2024-02-27    2024-02-28    2024-02-29    2024-03-01  \
# Ticker
# ADA-USD       0.624216      0.631059      0.655646      0.719081
# AVAX-USD     39.268646     40.294788     40.935387     42.855328
# BCH-USD     292.519379    296.793793    298.562378    316.125031
# BNB-USD     394.995636    415.771606    399.778717    407.810760
# BTC-USD   57085.371094  62504.789062  61198.382812  62440.632812
#
#             2024-03-02    2024-03-03    2024-03-04    2024-03-05  \
# Ticker
# ADA-USD       0.740928      0.728238      0.771294      0.693490
# AVAX-USD     44.333908     42.604858     43.088238     39.500137
# BCH-USD     500.806061    469.362793    470.423157    401.490845
# BNB-USD     410.985870    414.381073    419.035431    394.661743
columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_cleaned)

# %%
df_scaled = pd.DataFrame(scaled_data, index = df_cleaned.index, columns = df_cleaned.columns)
df_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, ADA-USD to XRP-USD
# Columns: 365 entries, 2024-02-27 to 2025-02-26
# dtypes: float64(365)
# memory usage: 85.8+ KB

# %%
df_scaled.head()
# Out:
#           2024-02-27  2024-02-28  2024-02-29  2024-03-01  2024-03-02  \
# Ticker
# ADA-USD    -0.278067   -0.277547   -0.277648   -0.277749   -0.278275
# AVAX-USD   -0.275344   -0.274995   -0.275007   -0.275041   -0.275451
# BCH-USD    -0.257498   -0.258491   -0.258114   -0.257474   -0.245880
# BNB-USD    -0.250277   -0.250835   -0.251477   -0.251580   -0.251699
# BTC-USD     3.744530    3.744277    3.735267    3.736150    3.740096
#
#           2024-03-03  2024-03-04  2024-03-05  2024-03-06  2024-03-07  ...  \
# Ticker                                                                ...
# ADA-USD    -0.278188   -0.277669   -0.277917   -0.278252   -0.278399  ...
# AVAX-USD   -0.275521   -0.275177   -0.275479   -0.275777   -0.275851  ...
# BCH-USD    -0.248345   -0.250012   -0.252733   -0.253096   -0.252539  ...
# BNB-USD    -0.251846   -0.253038   -0.253162   -0.252253   -0.249969  ...
# BTC-USD     3.744342    3.746037    3.730993    3.734856    3.731049  ...
#
#           2025-02-16  2025-02-17  2025-02-18  2025-02-19  2025-02-20  \
# Ticker
# ADA-USD    -0.273642   -0.273762   -0.273627   -0.273652   -0.273577
# AVAX-USD   -0.272638   -0.272746   -0.272670   -0.272697   -0.272583
# BCH-USD    -0.260046   -0.260227   -0.260367   -0.260268   -0.260288
# BNB-USD    -0.245534   -0.245823   -0.246411   -0.246505   -0.246755
# BTC-USD     3.741161    3.741416    3.747070    3.745283    3.744682
#
#           2025-02-21  2025-02-22  2025-02-23  2025-02-24  2025-02-26
# Ticker
# ADA-USD    -0.273563   -0.273728   -0.273829   -0.273472   -0.273652
# AVAX-USD   -0.272569   -0.272687   -0.272823   -0.272542   -0.272694
# BCH-USD    -0.260476   -0.260412   -0.260177   -0.260711   -0.260438
# BNB-USD    -0.246538   -0.245958   -0.246403   -0.246573   -0.245179
# BTC-USD     3.746848    3.742375    3.744196    3.736165    3.743501
#
# [5 rows x 365 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 3)
pca_result = pca.fit_transform(df_scaled)
df_pca = pd.DataFrame(pca_result, index = df_scaled.index, columns = ["PC1","PC2","PC3"])
df_pca.head()
# Out:
#                 PC1       PC2       PC3
# Ticker
# ADA-USD   -5.281320 -0.027985  0.000041
# AVAX-USD  -5.246398 -0.021290 -0.002314
# BCH-USD   -4.837393  0.047227 -0.004676
# BNB-USD   -4.649699  0.020615  0.008984
# BTC-USD   71.476327 -0.049021 -0.056482

# %%
import matplotlib.pyplot as plt

# Scatter plot of PCA components
plt.figure(figsize=(10, 6))
plt.scatter(df_pca['PC1'], df_pca['PC2'], color='blue', alpha=0.7)

# Annotate points with cryptocurrency names
for i, txt in enumerate(df_cleaned.index):
    plt.annotate(txt, (df_pca['PC1'][i], df_pca['PC2'][i]), fontsize=9, alpha=0.7)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of 30 Cryptocurrencies")
plt.grid(True)
plt.show()
# Out:
# C:\Users\Solent\AppData\Local\Temp\ipykernel_20596\1175188315.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(txt, (df_pca['PC1'][i], df_pca['PC2'][i]), fontsize=9, alpha=0.7)

# %%
from mpl_toolkits.mplot3d import Axes3D


# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot with PCA components
ax.scatter(df_pca['PC1'], df_pca['PC2'], df_pca['PC3'], color='blue', alpha=0.7)

# Annotate points with cryptocurrency names
for i, txt in enumerate(df_cleaned.index):
    ax.text(df_pca['PC1'][i], df_pca['PC2'][i], df_pca['PC3'][i], txt, fontsize=8, alpha=0.7)

ax.set_xlabel("Principal Component 1")
ax.set_ylabel("Principal Component 2")
ax.set_zlabel("Principal Component 3")
ax.set_title("3D PCA Visualization of 30 Cryptocurrencies")

plt.show()
# Out:
# C:\Users\Solent\AppData\Local\Temp\ipykernel_20596\1947469111.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ax.text(df_pca['PC1'][i], df_pca['PC2'][i], df_pca['PC3'][i], txt, fontsize=8, alpha=0.7)

# %%
import numpy as np
explained_variance = np.cumsum(pca.explained_variance_ratio_)  
print(explained_variance)
# Out:
# [0.99996112 0.9999986  0.9999992 ]

# %%
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
crypto_names = df_cleaned.index
pca_components = df_pca.iloc[:,0:3]

#applying KMeans
kmeans  = KMeans(n_clusters = 4, random_state = 42, n_init="auto")
kmeans_labels = kmeans.fit_predict(pca_components)
# Out:
# C:\Users\Solent\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
#applying Hierarchical clustering using ward's method

linkage_matrix = linkage(pca_components, method="ward", metric="euclidean")
hierarchical_labels = fcluster(linkage_matrix, 4, criterion = "maxclust")-1

# %%
#comparing quality metrics for both clustering models
kmeans_silhouette = silhouette_score(pca_components, kmeans_labels)
hierarchical_silhouette = silhouette_score(pca_components, hierarchical_labels)

kmeans_ch = calinski_harabasz_score(pca_components, kmeans_labels)
hierarchical_ch = calinski_harabasz_score(pca_components, hierarchical_labels)

kmeans_db = davies_bouldin_score(pca_components, kmeans_labels)
hierarchical_db = davies_bouldin_score(pca_components, hierarchical_labels)

# %%
# Print comparison metrics
print("Clustering Quality Metrics (4 clusters):")
print("-" * 50)
print(f"K-means Silhouette Score: {kmeans_silhouette:.4f}")
print(f"Hierarchical Silhouette Score: {hierarchical_silhouette:.4f}")
print()
print(f"K-means Calinski-Harabasz Score: {kmeans_ch:.2f}")
print(f"Hierarchical Calinski-Harabasz Score: {hierarchical_ch:.2f}")
print()
print(f"K-means Davies-Bouldin Score: {kmeans_db:.4f}")
print(f"Hierarchical Davies-Bouldin Score: {hierarchical_db:.4f}")
print("-" * 50)
# Out:
# Clustering Quality Metrics (4 clusters):
# --------------------------------------------------
# K-means Silhouette Score: 0.8692
# Hierarchical Silhouette Score: 0.8692
#
# K-means Calinski-Harabasz Score: 1057844.31
# Hierarchical Calinski-Harabasz Score: 1057844.31
#
# K-means Davies-Bouldin Score: 0.1323
# Hierarchical Davies-Bouldin Score: 0.1323
# --------------------------------------------------

# %%
fig = plt.figure(figsize=(15, 6))

# K-means plot
ax1 = fig.add_subplot(121, projection='3d')
colors = ['blue', 'red', 'green', 'purple']

for i in range(4):
    cluster_points = pca_components[kmeans_labels == i]
    ax1.scatter(
        cluster_points.iloc[:, 0],
        cluster_points.iloc[:, 1],
        cluster_points.iloc[:, 2],
        c=colors[i],
        label=f'Cluster {i+1}',
        alpha=0.7,
        s=80
    )

ax1.set_title('K-means Clustering (4 clusters)')
ax1.set_xlabel('PCA Component 1')
ax1.set_ylabel('PCA Component 2')
ax1.set_zlabel('PCA Component 3')
ax1.legend()

# Hierarchical plot
ax2 = fig.add_subplot(122, projection='3d')

for i in range(4):
    cluster_points = pca_components[hierarchical_labels == i]
    ax2.scatter(
        cluster_points.iloc[:, 0],
        cluster_points.iloc[:, 1],
        cluster_points.iloc[:, 2],
        c=colors[i],
        label=f'Cluster {i+1}',
        alpha=0.7,
        s=80
    )

ax2.set_title('Hierarchical Clustering (4 clusters)')
ax2.set_xlabel('PCA Component 1')
ax2.set_ylabel('PCA Component 2')
ax2.set_zlabel('PCA Component 3')
ax2.legend()

plt.tight_layout()

# %%
kmeans_results = pd.DataFrame({
    'Cryptocurrency': crypto_names,
    'Cluster': kmeans_labels + 1  # Making clusters start from 1 for readability
})

hierarchical_results = pd.DataFrame({
    'Cryptocurrency': crypto_names,
    'Cluster': hierarchical_labels + 1 
})

# Print K-means clusters
print("\nK-means Clustering Results:")
print("=" * 30)
for cluster in range(1, 5):
    crypto_in_cluster = kmeans_results[kmeans_results['Cluster'] == cluster]['Cryptocurrency'].tolist()
    print(f"Cluster {cluster}: {','.join(crypto_in_cluster)}")

# Print Hierarchical clusters
print("\nHierarchical Clustering Results:")
print("=" * 30)
for cluster in range(1, 5):
    crypto_in_cluster = hierarchical_results[hierarchical_results['Cluster'] == cluster]['Cryptocurrency'].tolist()
    print(f"Cluster {cluster}: {', '.join(crypto_in_cluster)}")
# Out:
# K-means Clustering Results:
# ==============================
# Cluster 1: ADA-USD,AVAX-USD,DAI-USD,DOGE-USD,DOT-USD,FIL-USD,HBAR-USD,ICP-USD,LDO-USD,LEO-USD,LINK-USD,LTC-USD,MATIC-USD,OKB-USD,SHIB-USD,SOL-USD,SUI-USD,TON-USD,TRX-USD,TUSD-USD,USDC-USD,USDT-USD,XLM-USD,XMR-USD,XRP-USD
# Cluster 2: BTC-USD,WBTC-USD
# Cluster 3: ETH-USD
# Cluster 4: BCH-USD,BNB-USD
#
# Hierarchical Clustering Results:
# ==============================
# Cluster 1: BTC-USD, WBTC-USD
# Cluster 2: BCH-USD, BNB-USD
# Cluster 3: ADA-USD, AVAX-USD, DAI-USD, DOGE-USD, DOT-USD, FIL-USD, HBAR-USD, ICP-USD, LDO-USD, LEO-USD, LINK-USD, LTC-USD, MATIC-USD, OKB-USD, SHIB-USD, SOL-USD, SUI-USD, TON-USD, TRX-USD, TUSD-USD, USDC-USD, USDT-USD, XLM-USD, XMR-USD, XRP-USD
# Cluster 4: ETH-USD

# %% [markdown]
# # Correlation

# %%
# Transpose the dataset to have cryptos as columns and days as rows
df_T = df_scaled.T
df_T.head(366)
# Out:
# Ticker       ADA-USD  AVAX-USD   BCH-USD   BNB-USD   BTC-USD   DAI-USD  \
# 2024-02-28 -0.268973 -0.277551
# 2024-02-29 -0.268696 -0.277653
# 2024-03-01 -0.268604 -0.277757
# 2024-03-02 -0.268953 -0.278281
# ...              ...       ...
# 2025-02-21 -0.263834 -0.273487
# 2025-02-22 -0.263998 -0.273653
# 2025-02-23 -0.263998 -0.273754
# 2025-02-24 -0.263554 -0.273402
# 2025-02-26 -0.263880 -0.273579
#
# [365 rows x 30 columns]

# %%
# Compute correlation matrix
correlation_matrix = df_T.corr()

# Display correlation matrix
print(correlation_matrix)
# Out:
# Ticker      ADA-USD  AVAX-USD   BCH-USD   BNB-USD   BTC-USD   DAI-USD  \
# Ticker
# ADA-USD    1.000000  0.949628 -0.678501 -0.415788  0.637863  0.999955
# AVAX-USD   0.949628  1.000000 -0.547557 -0.521086  0.672186  0.947842
# BCH-USD   -0.678501 -0.547557  1.000000  0.270449 -0.369908 -0.679904
# BNB-USD   -0.415788 -0.521086  0.270449  1.000000 -0.244226 -0.409122
# BTC-USD    0.637863  0.672186 -0.369908 -0.244226  1.000000  0.636808
# DAI-USD    0.999955  0.947842 -0.679904 -0.409122  0.636808  1.000000
# DOGE-USD   0.999992  0.948816 -0.678652 -0.413200  0.637460  0.999978
# DOT-USD    0.999117  0.959924 -0.669968 -0.442003  0.642579  0.998782
# ETH-USD   -0.988525 -0.942208  0.599181  0.314808 -0.643278 -0.989109
# FIL-USD    0.998650  0.962373 -0.663440 -0.442424  0.643027  0.998337
# HBAR-USD   0.999993  0.948773 -0.679036 -0.413170  0.637251  0.999979
# ICP-USD    0.996397  0.966021 -0.631433 -0.431962  0.644877  0.996084
# LDO-USD    0.999900  0.951699 -0.678790 -0.424014  0.636892  0.999796
# LEO-USD    0.999848  0.946912 -0.681097 -0.406081  0.635343  0.999900
# LINK-USD   0.995595  0.963147 -0.671052 -0.475928  0.642028  0.994834
# LTC-USD    0.933484  0.943563 -0.528724 -0.509203  0.596566  0.931695
# MATIC-USD  0.999991  0.949904 -0.678297 -0.415144  0.637667  0.999965
# OKB-USD    0.957941  0.974919 -0.576858 -0.442846  0.626183  0.957417
# SHIB-USD   0.999987  0.948518 -0.679198 -0.412166  0.637175  0.999988
# SOL-USD    0.796314  0.793995 -0.425957 -0.250447  0.536293  0.796873
# SUI-USD    0.999987  0.948518 -0.679197 -0.412164  0.637175  0.999988
# TON-USD    0.999789  0.953616 -0.669462 -0.418756  0.640080  0.999720
# TRX-USD    0.999987  0.948497 -0.679322 -0.412027  0.637299  0.999988
# TUSD-USD   0.999956  0.947861 -0.679872 -0.409142  0.636818  1.000000
# USDC-USD   0.999955  0.947842 -0.679904 -0.409121  0.636807  1.000000
# USDT-USD   0.999956  0.947844 -0.679902 -0.409128  0.636809  1.000000
# WBTC-USD  -0.350183 -0.412149  0.197805  0.173653 -0.941745 -0.348545
# XLM-USD    0.999995  0.948840 -0.678926 -0.413488  0.637389  0.999976
# XMR-USD    0.701945  0.526778 -0.763815  0.046886  0.388046  0.706477
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title("Cryptocurrency Correlation Heatmap")
plt.show()

# %%
correlation_matrix.index.name = None
correlation_pairs = correlation_matrix.unstack().reset_index()
correlation_pairs.head()
# Out:
#     Ticker   level_1         0
# 0  ADA-USD   ADA-USD  1.000000
# 1  ADA-USD  AVAX-USD  0.949628
# 2  ADA-USD   BCH-USD -0.678501
# 3  ADA-USD   BNB-USD -0.415788
# 4  ADA-USD   BTC-USD  0.637863

# %%
correlation_pairs.columns = ['Crypto1', 'Crypto2', 'Correlation']

# Remove self-correlations (where Crypto1 == Crypto2)
correlation_pairs = correlation_pairs[correlation_pairs['Crypto1'] != correlation_pairs['Crypto2']]

# Get the most positively and negatively correlated pairs
top_positive_correlations = correlation_pairs.sort_values(by='Correlation', ascending=False).head(8)
top_negative_correlations = correlation_pairs.sort_values(by='Correlation', ascending=True).head(8)
print("Top Positive Correlations:")
print(top_positive_correlations[::2])
print("\nTop Negative Correlations:")
print(top_negative_correlations[::2])
# Out:
# Top Positive Correlations:
#       Crypto1   Crypto2  Correlation
# 618   SUI-USD  SHIB-USD          1.0
# 725  USDC-USD   DAI-USD          1.0
# 755  USDT-USD   DAI-USD          1.0
# 745  USDC-USD  USDT-USD          1.0
#
# Top Negative Correlations:
#       Crypto1  Crypto2  Correlation
# 251   ETH-USD  ICP-USD    -0.989812
# 638   TON-USD  ETH-USD    -0.989257
# 398   LEO-USD  ETH-USD    -0.989242
# 698  TUSD-USD  ETH-USD    -0.989113

# %%
from sklearn.metrics import pairwise_distances_argmin_min
# Get cluster centroids in PCA space
centroids = kmeans.cluster_centers_

# Find closest asset to each centroid in PCA space
closest_indices, _ = pairwise_distances_argmin_min(centroids, df_pca)

# Get asset names of best representatives
representatives = df_pca.iloc[closest_indices].index.values
cluster_labels = [f"Cluster {i+1}" for i in range(len(representatives))]

# Create dictionary of best representatives
best_representatives = dict(zip(cluster_labels, representatives))

print(best_representatives)
# Out:
# {'Cluster 1': 'LINK-USD', 'Cluster 2': 'WBTC-USD', 'Cluster 3': 'ETH-USD', 'Cluster 4': 'BCH-USD'}

# %%
import yfinance as yf
import pandas as pd

# Define the clusters
clusters = {
    "Cluster 1": ["ADA-USD", "AVAX-USD", "DAI-USD", "DOGE-USD", "DOT-USD", "FIL-USD", "HBAR-USD", "ICP-USD", 
                  "LDO-USD", "LEO-USD", "LINK-USD", "LTC-USD", "MATIC-USD", "OKB-USD", "SHIB-USD", "SOL-USD", 
                  "SUI-USD", "TON-USD", "TRX-USD", "TUSD-USD", "USDC-USD", "USDT-USD", "XLM-USD", "XMR-USD", "XRP-USD"],
    "Cluster 2": ["BTC-USD", "WBTC-USD"],
    "Cluster 3": ["ETH-USD"],
    "Cluster 4": ["BCH-USD", "BNB-USD"]
}

# Fetch market data for each cluster
market_data = []

for cluster, tickers in clusters.items():
    for ticker in tickers:
        try:
            crypto = yf.Ticker(ticker)
            info = crypto.info  # Fetch metadata
            
            market_data.append({
                "Cluster": cluster,
                "Asset": ticker,
                "Market_Cap": info.get("marketCap", "N/A"),
                "Volume": info.get("volume24Hr", "N/A"),
                "Price": info.get("regularMarketPrice", "N/A")
            })
        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

# Convert to DataFrame
df_market = pd.DataFrame(market_data)

# Display the market data
print(df_market)
# Out:
#       Cluster      Asset     Market_Cap       Volume         Price
# 0   Cluster 1    ADA-USD    32084301824   2633449472      0.910859
# 1   Cluster 1   AVAX-USD     8754080768    489898592     21.135576
# 2   Cluster 1    DAI-USD     5365708800     99577376      1.000061
# 3   Cluster 1   DOGE-USD    30027352064   1801369344      0.202448
# 4   Cluster 1    DOT-USD     6925639168    189110416      4.453104
# 5   Cluster 1    FIL-USD     1989326592    140701920      3.096489
# 6   Cluster 1   HBAR-USD    10053117952    412335360      0.238126
# 7   Cluster 1    ICP-USD     2992254976     71516552      6.215340
# 8   Cluster 1    LDO-USD     1035600640     91789376      1.153741
# 9   Cluster 1    LEO-USD     9154569216      2819356      9.907552
# 10  Cluster 1   LINK-USD    10936380416   1080379136     17.138975
# 11  Cluster 1    LTC-USD     7822313984    990289920    103.526634
# 12  Cluster 1  MATIC-USD      480627296      3961105      0.251140
# 13  Cluster 1    OKB-USD     2589982208      3789394     43.166370
# 14  Cluster 1   SHIB-USD     7923457536    213647760      0.000013
# 15  Cluster 1    SOL-USD    73062096896   4203297792    143.788760
# 16  Cluster 1    SUI-USD              0           10      0.000300
# 17  Cluster 1    TON-USD              0         9596      0.155637
# 18  Cluster 1    TRX-USD    20671096832    569305024      0.240220
# 19  Cluster 1   TUSD-USD      494436384     56102788      0.997821
# 20  Cluster 1   USDC-USD    57284124672   9562315776      1.000245
# 21  Cluster 1   USDT-USD   142739750912  87385956352      1.000150
# 22  Cluster 1    XLM-USD     9128268800    283803520      0.297228
# 23  Cluster 1    XMR-USD     4218205952     75220328    228.669400
# 24  Cluster 1    XRP-USD   151075307520   6904922624      2.607006
# 25  Cluster 2    BTC-USD  1787838595072  47601508352  90143.460000
# 26  Cluster 2   WBTC-USD    11637538816    291981728  90089.516000
# 27  Cluster 3    ETH-USD   265649192960  18255640576   2202.822000
# 28  Cluster 4    BCH-USD     7837591552    686999360    395.065400
# 29  Cluster 4    BNB-USD    85025857536   1626160640    596.774840

# %%
highest_market_cap_assets = df_market.loc[df_market.groupby("Cluster")["Market_Cap"].idxmax()]
print("Assets with the highest Market Cap in each cluster:\n")
print(highest_market_cap_assets[["Cluster", "Asset", "Market_Cap"]])
# Out:
# Assets with the highest Market Cap in each cluster:
#
#       Cluster    Asset     Market_Cap
# 24  Cluster 1  XRP-USD   151075307520
# 25  Cluster 2  BTC-USD  1787838595072
# 27  Cluster 3  ETH-USD   265649192960
# 29  Cluster 4  BNB-USD    85025857536
