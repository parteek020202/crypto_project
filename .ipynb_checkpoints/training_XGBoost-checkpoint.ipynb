# %%
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import TimeSeriesSplit
import joblib
import optuna  # For hyperparameter tuning

# Tickers
tickers = ["BNB-USD", "BTC-USD", "ETH-USD", "XRP-USD"]

# Prepare data with feature engineering
def prepare_data(df):
    features = ["Open", "High", "Low", "Close", "Volume", "Lag1", "Lag7", "SMA7", "RSI14", "MACD", "Returns", "Volatility"]
    X = df[features].values
    y = df["Target"].values
    return X, y, features

# Objective function for Optuna hyperparameter tuning
def objective(trial, X_train_scaled, y_train, X_test_scaled, y_test):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'random_state': 42
    }
    
    model = XGBRegressor(**params)
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    return mse

# Train and evaluate XGBoost model
for ticker in tickers:
    print(f"\nTraining XGBoost for {ticker}...")
    
    # Load data
    df = pd.read_csv(f"{ticker}_processed.csv", index_col="Date", parse_dates=True)
    X, y, feature_names = prepare_data(df)
    
    # Split data (80% train, 20% test, no shuffle for time series)
    train_size = int(len(X) * 0.8)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    
    # Scale features
    scaler_X = StandardScaler()
    X_train_scaled = scaler_X.fit_transform(X_train)
    X_test_scaled = scaler_X.transform(X_test)
    
    # Hyperparameter tuning with Optuna
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: objective(trial, X_train_scaled, y_train, X_test_scaled, y_test), n_trials=30)
    best_params = study.best_params
    print(f"Best parameters for {ticker}: {best_params}")
    
    # Train final model with best parameters
    model = XGBRegressor(**best_params)
    model.fit(X_train_scaled, y_train)
    
    # Predict and evaluate
    y_pred = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    mape = mean_absolute_percentage_error(y_test, y_pred) * 100
    test_dates = df.index[train_size:]
    actual_series = pd.Series(y_test, index=test_dates)
    pred_series = pd.Series(y_pred, index=test_dates)
    actual_direction = (actual_series.shift(-1) > actual_series).iloc[:-1].astype(int)
    predicted_direction = (pred_series.shift(-1) > pred_series).iloc[:-1].astype(int)
    directional_accuracy = (actual_direction == predicted_direction).mean() * 100
    
    print(f"XGBoost Results for {ticker}:")
    print(f"MSE: {mse:.2f}")
    print(f"MAPE: {mape:.2f}%")
    print(f"Directional Accuracy: {directional_accuracy:.2f}%")
    
    # Feature importance
    importance = model.feature_importances_
    for feat, imp in zip(feature_names, importance):
        print(f"Feature {feat}: {imp:.4f}")
    
    # Save model and scaler
    joblib.dump(model, f"{ticker}_xgboost_model.pkl")
    joblib.dump(scaler_X, f"{ticker}_scaler_X_xgb.pkl")
    print(f"Model and scaler saved for {ticker}")
# Out:
# [I 2025-03-11 02:26:44,761] A new study created in memory with name: no-name-2cb05c60-0bfc-4fc0-9e79-12cf2393248e
# Training XGBoost for BNB-USD...
# [I 2025-03-11 02:26:45,311] Trial 0 finished with value: 2521.2303507776387 and parameters: {'n_estimators': 342, 'max_depth': 14, 'learning_rate': 0.013354108105531136, 'subsample': 0.6935739745886809, 'colsample_bytree': 0.6798556588365028}. Best is trial 0 with value: 2521.2303507776387.
# [I 2025-03-11 02:26:45,817] Trial 1 finished with value: 2074.9031376856124 and parameters: {'n_estimators': 365, 'max_depth': 9, 'learning_rate': 0.017979624336556574, 'subsample': 0.931905949910842, 'colsample_bytree': 0.6190569286804392}. Best is trial 1 with value: 2074.9031376856124.
# [I 2025-03-11 02:26:48,205] Trial 12 finished with value: 1199.906930236899 and parameters: {'n_estimators': 166, 'max_depth': 3, 'learning_rate': 0.09749710465642829, 'subsample': 0.6177838155057531, 'colsample_bytree': 0.7467056852717273}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:48,329] Trial 13 finished with value: 2258.4406712272385 and parameters: {'n_estimators': 165, 'max_depth': 6, 'learning_rate': 0.04030213835861604, 'subsample': 0.6108312760918566, 'colsample_bytree': 0.6145791564521721}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:48,449] Trial 14 finished with value: 1315.9228615377178 and parameters: {'n_estimators': 306, 'max_depth': 3, 'learning_rate': 0.036177401221475544, 'subsample': 0.6014999882249572, 'colsample_bytree': 0.7650987963620162}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:48,519] Trial 15 finished with value: 1314.9429639376276 and parameters: {'n_estimators': 162, 'max_depth': 3, 'learning_rate': 0.06437927119655425, 'subsample': 0.7028060153898714, 'colsample_bytree': 0.9983789322269463}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:48,914] Trial 16 finished with value: 1606.481097087766 and parameters: {'n_estimators': 199, 'max_depth': 11, 'learning_rate': 0.09921277325364507, 'subsample': 0.7590488148543449, 'colsample_bytree': 0.6656028863504042}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,360] Trial 17 finished with value: 2161.423436696912 and parameters: {'n_estimators': 288, 'max_depth': 10, 'learning_rate': 0.037051121159622794, 'subsample': 0.6578364467228807, 'colsample_bytree': 0.6667613894003913}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,470] Trial 18 finished with value: 2293.0727865873764 and parameters: {'n_estimators': 158, 'max_depth': 6, 'learning_rate': 0.05227614537385468, 'subsample': 0.6542746261660249, 'colsample_bytree': 0.7248487784309615}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,624] Trial 19 finished with value: 2053.092583263042 and parameters: {'n_estimators': 284, 'max_depth': 5, 'learning_rate': 0.02853275080713386, 'subsample': 0.7228002824534768, 'colsample_bytree': 0.7810441929326714}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,796] Trial 20 finished with value: 2027.1007366760878 and parameters: {'n_estimators': 147, 'max_depth': 8, 'learning_rate': 0.07386773224376292, 'subsample': 0.7961320910736411, 'colsample_bytree': 0.6407919654668854}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,871] Trial 21 finished with value: 1180.585543905431 and parameters: {'n_estimators': 199, 'max_depth': 3, 'learning_rate': 0.06636455239169074, 'subsample': 0.7035739045847447, 'colsample_bytree': 0.9996196546279519}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:49,962] Trial 22 finished with value: 1677.4192053384234 and parameters: {'n_estimators': 204, 'max_depth': 4, 'learning_rate': 0.08311070329710732, 'subsample': 0.6355633743883999, 'colsample_bytree': 0.9926706956598426}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:50,057] Trial 23 finished with value: 1840.6388876571827 and parameters: {'n_estimators': 232, 'max_depth': 4, 'learning_rate': 0.04283049310498825, 'subsample': 0.6878714159383675, 'colsample_bytree': 0.8256070171866166}. Best is trial 4 with value: 1038.589731425047.
# [I 2025-03-11 02:26:50,128] Trial 24 finished with value: 1013.3054441883631 and parameters: {'n_estimators': 191, 'max_depth': 3, 'learning_rate': 0.06831844403803894, 'subsample': 0.750525867157928, 'colsample_bytree': 0.7604137412503714}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:50,332] Trial 25 finished with value: 1951.86209676671 and parameters: {'n_estimators': 276, 'max_depth': 6, 'learning_rate': 0.053110862499391044, 'subsample': 0.7644153789671437, 'colsample_bytree': 0.695467407476195}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:50,426] Trial 26 finished with value: 2162.542869166438 and parameters: {'n_estimators': 132, 'max_depth': 4, 'learning_rate': 0.0743567566030802, 'subsample': 0.8802648565341052, 'colsample_bytree': 0.9643203320729693}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:51,165] Trial 27 finished with value: 1956.8901482912454 and parameters: {'n_estimators': 193, 'max_depth': 15, 'learning_rate': 0.049164831733344745, 'subsample': 0.7291984134121934, 'colsample_bytree': 0.8871148282965924}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:51,358] Trial 28 finished with value: 1927.5522327898136 and parameters: {'n_estimators': 215, 'max_depth': 7, 'learning_rate': 0.03176159301879057, 'subsample': 0.8181684118983599, 'colsample_bytree': 0.8009519932495435}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:51,482] Trial 29 finished with value: 2671.8297553043417 and parameters: {'n_estimators': 261, 'max_depth': 5, 'learning_rate': 0.015334576023241928, 'subsample': 0.6866377532508451, 'colsample_bytree': 0.6440290211669123}. Best is trial 24 with value: 1013.3054441883631.
# [I 2025-03-11 02:26:51,545] A new study created in memory with name: no-name-22e0b33d-7ab9-4e94-b3f6-a8ce2fd52f45
# Best parameters for BNB-USD: {'n_estimators': 191, 'max_depth': 3, 'learning_rate': 0.06831844403803894, 'subsample': 0.750525867157928, 'colsample_bytree': 0.7604137412503714}
# XGBoost Results for BNB-USD:
# MSE: 1305.47
# MAPE: 4.21%
# Directional Accuracy: 52.14%
# Feature Open: 0.2025
# Feature High: 0.4523
# Feature Low: 0.1163
# Feature Close: 0.1029
# Feature Volume: 0.0009
# Feature Lag1: 0.0353
# Feature Lag7: 0.0017
# Feature SMA7: 0.0847
# Feature RSI14: 0.0011
# Feature MACD: 0.0007
# Feature Returns: 0.0007
# Feature Volatility: 0.0008
# Model and scaler saved for BNB-USD
#
# Training XGBoost for BTC-USD...
# [I 2025-03-11 02:26:51,920] Trial 0 finished with value: 864983926.1659667 and parameters: {'n_estimators': 284, 'max_depth': 11, 'learning_rate': 0.00990590316297125, 'subsample': 0.9704539771645309, 'colsample_bytree': 0.701664926976546}. Best is trial 0 with value: 864983926.1659667.
# [I 2025-03-11 02:26:57,983] Trial 23 finished with value: 774515208.4736953 and parameters: {'n_estimators': 453, 'max_depth': 4, 'learning_rate': 0.019214250435131145, 'subsample': 0.6091272806178093, 'colsample_bytree': 0.6710738781019884}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:58,218] Trial 24 finished with value: 778116681.5864675 and parameters: {'n_estimators': 382, 'max_depth': 6, 'learning_rate': 0.013146781197246965, 'subsample': 0.6980325203979171, 'colsample_bytree': 0.6029139124132329}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:58,323] Trial 25 finished with value: 720481748.7578692 and parameters: {'n_estimators': 317, 'max_depth': 3, 'learning_rate': 0.02466834801069564, 'subsample': 0.6456063660888126, 'colsample_bytree': 0.6637092124776727}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:58,570] Trial 26 finished with value: 832755721.6934172 and parameters: {'n_estimators': 432, 'max_depth': 6, 'learning_rate': 0.007493389763501895, 'subsample': 0.7670422009868775, 'colsample_bytree': 0.6311254335604113}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:58,731] Trial 27 finished with value: 767114700.5254446 and parameters: {'n_estimators': 412, 'max_depth': 4, 'learning_rate': 0.016591406144232473, 'subsample': 0.8478664092625019, 'colsample_bytree': 0.7391756389348254}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:59,042] Trial 28 finished with value: 782251008.4392158 and parameters: {'n_estimators': 473, 'max_depth': 6, 'learning_rate': 0.012010384073860295, 'subsample': 0.6256087524176593, 'colsample_bytree': 0.6846410798116644}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:59,364] Trial 29 finished with value: 837832624.8601384 and parameters: {'n_estimators': 282, 'max_depth': 11, 'learning_rate': 0.010446654503657131, 'subsample': 0.7160081017470781, 'colsample_bytree': 0.7137679945655698}. Best is trial 10 with value: 703029946.6543176.
# [I 2025-03-11 02:26:59,478] A new study created in memory with name: no-name-eef420e4-f9dc-4baf-9f5d-feefb0b547f0
# Best parameters for BTC-USD: {'n_estimators': 388, 'max_depth': 3, 'learning_rate': 0.014132988171124437, 'subsample': 0.6073793893110279, 'colsample_bytree': 0.608514008942836}
# XGBoost Results for BTC-USD:
# MSE: 722784827.29
# MAPE: 25.20%
# Directional Accuracy: 45.71%
# Feature Open: 0.2924
# Feature High: 0.1235
# Feature Low: 0.1804
# Feature Close: 0.1658
# Feature Volume: 0.0006
# Feature Lag1: 0.2032
# Feature Lag7: 0.0068
# Feature SMA7: 0.0235
# Feature RSI14: 0.0014
# Feature MACD: 0.0008
# Feature Returns: 0.0009
# Feature Volatility: 0.0007
# Model and scaler saved for BTC-USD
#
# Training XGBoost for ETH-USD...
# [I 2025-03-11 02:27:00,082] Trial 0 finished with value: 19991.24959377321 and parameters: {'n_estimators': 483, 'max_depth': 9, 'learning_rate': 0.007755052480125277, 'subsample': 0.6687351983549851, 'colsample_bytree': 0.968322322165359}. Best is trial 0 with value: 19991.24959377321.
# [I 2025-03-11 02:27:10,427] Trial 22 finished with value: 18276.164484046454 and parameters: {'n_estimators': 339, 'max_depth': 9, 'learning_rate': 0.012416944325837521, 'subsample': 0.6064127613298845, 'colsample_bytree': 0.6424892833022301}. Best is trial 21 with value: 17851.736969646834.
# [I 2025-03-11 02:27:10,578] Trial 23 finished with value: 16733.989142209924 and parameters: {'n_estimators': 419, 'max_depth': 4, 'learning_rate': 0.016318972624234675, 'subsample': 0.7159220430878502, 'colsample_bytree': 0.7206079163500086}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:10,706] Trial 24 finished with value: 26194.236629773117 and parameters: {'n_estimators': 428, 'max_depth': 3, 'learning_rate': 0.005143985325995689, 'subsample': 0.7043027797067691, 'colsample_bytree': 0.7071894551137968}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:10,935] Trial 25 finished with value: 17556.207779665787 and parameters: {'n_estimators': 488, 'max_depth': 5, 'learning_rate': 0.018721586475408246, 'subsample': 0.7085397257301193, 'colsample_bytree': 0.7469430826638448}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:11,180] Trial 26 finished with value: 17750.15534388892 and parameters: {'n_estimators': 492, 'max_depth': 5, 'learning_rate': 0.01622359615568009, 'subsample': 0.8317999193525744, 'colsample_bytree': 0.7558762053715876}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:11,363] Trial 27 finished with value: 17184.26563565655 and parameters: {'n_estimators': 499, 'max_depth': 4, 'learning_rate': 0.016942402098015567, 'subsample': 0.8244118841664224, 'colsample_bytree': 0.7575513256413883}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:11,528] Trial 28 finished with value: 18057.754738882923 and parameters: {'n_estimators': 464, 'max_depth': 4, 'learning_rate': 0.02182744270534161, 'subsample': 0.7627037833352075, 'colsample_bytree': 0.8111799368573551}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:11,697] Trial 29 finished with value: 17111.545179118923 and parameters: {'n_estimators': 460, 'max_depth': 4, 'learning_rate': 0.008769737814470978, 'subsample': 0.8227701195819663, 'colsample_bytree': 0.7840579476860016}. Best is trial 23 with value: 16733.989142209924.
# [I 2025-03-11 02:27:11,850] A new study created in memory with name: no-name-e4649e7f-3588-470d-9ca7-95e6dc6e4f01
# Best parameters for ETH-USD: {'n_estimators': 419, 'max_depth': 4, 'learning_rate': 0.016318972624234675, 'subsample': 0.7159220430878502, 'colsample_bytree': 0.7206079163500086}
# XGBoost Results for ETH-USD:
# MSE: 16576.59
# MAPE: 3.33%
# Directional Accuracy: 46.43%
# Feature Open: 0.0474
# Feature High: 0.1844
# Feature Low: 0.3089
# Feature Close: 0.4047
# Feature Volume: 0.0016
# Feature Lag1: 0.0250
# Feature Lag7: 0.0022
# Feature SMA7: 0.0181
# Feature RSI14: 0.0030
# Feature MACD: 0.0020
# Feature Returns: 0.0015
# Feature Volatility: 0.0012
# Model and scaler saved for ETH-USD
#
# Training XGBoost for XRP-USD...
# [I 2025-03-11 02:27:12,603] Trial 0 finished with value: 2.2860067452442716 and parameters: {'n_estimators': 413, 'max_depth': 13, 'learning_rate': 0.029443751583677284, 'subsample': 0.724527914601244, 'colsample_bytree': 0.9690667117959306}. Best is trial 0 with value: 2.2860067452442716.
# [I 2025-03-11 02:27:13,735] Trial 1 finished with value: 2.2673195241285864 and parameters: {'n_estimators': 468, 'max_depth': 13, 'learning_rate': 0.01273017098648033, 'subsample': 0.9212748124031308, 'colsample_bytree': 0.8333641477844607}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:13,901] Trial 2 finished with value: 2.3219044487267437 and parameters: {'n_estimators': 488, 'max_depth': 4, 'learning_rate': 0.009875848703126425, 'subsample': 0.7140663171608429, 'colsample_bytree': 0.6059027753594435}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:14,332] Trial 3 finished with value: 2.298082284147266 and parameters: {'n_estimators': 248, 'max_depth': 14, 'learning_rate': 0.049937005522878976, 'subsample': 0.8086706125544343, 'colsample_bytree': 0.6857849258037138}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:14,389] Trial 4 finished with value: 2.3227370429007332 and parameters: {'n_estimators': 187, 'max_depth': 3, 'learning_rate': 0.04670605376029827, 'subsample': 0.8694872589279841, 'colsample_bytree': 0.713261505717822}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:14,620] Trial 5 finished with value: 2.2868092511552596 and parameters: {'n_estimators': 305, 'max_depth': 7, 'learning_rate': 0.05877270851291111, 'subsample': 0.8529539121825866, 'colsample_bytree': 0.7116697518457052}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:15,850] Trial 6 finished with value: 2.3065899064504127 and parameters: {'n_estimators': 438, 'max_depth': 13, 'learning_rate': 0.0079251252110523, 'subsample': 0.8768631362122823, 'colsample_bytree': 0.7954113589987908}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:16,169] Trial 7 finished with value: 2.3013862095027022 and parameters: {'n_estimators': 444, 'max_depth': 7, 'learning_rate': 0.05789585527191863, 'subsample': 0.7198132268168671, 'colsample_bytree': 0.6558413963958951}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:16,697] Trial 8 finished with value: 2.2868425811508994 and parameters: {'n_estimators': 136, 'max_depth': 14, 'learning_rate': 0.04422811423222086, 'subsample': 0.8877373013968135, 'colsample_bytree': 0.7310648728109148}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:17,239] Trial 9 finished with value: 2.414064993518814 and parameters: {'n_estimators': 217, 'max_depth': 14, 'learning_rate': 0.008974924718626067, 'subsample': 0.6535693621176356, 'colsample_bytree': 0.6381523830588842}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:18,076] Trial 10 finished with value: 2.2705843617431767 and parameters: {'n_estimators': 330, 'max_depth': 10, 'learning_rate': 0.015321733004786882, 'subsample': 0.977010056321379, 'colsample_bytree': 0.9528267621546342}. Best is trial 1 with value: 2.2673195241285864.
# [I 2025-03-11 02:27:19,077] Trial 11 finished with value: 2.267156644873442 and parameters: {'n_estimators': 342, 'max_depth': 10, 'learning_rate': 0.015930437538157247, 'subsample': 0.9709970072016428, 'colsample_bytree': 0.9340217678765093}. Best is trial 11 with value: 2.267156644873442.
# [I 2025-03-11 02:27:19,982] Trial 12 finished with value: 2.2729975392798334 and parameters: {'n_estimators': 363, 'max_depth': 10, 'learning_rate': 0.01566581303992035, 'subsample': 0.9947620896210818, 'colsample_bytree': 0.882069479203397}. Best is trial 11 with value: 2.267156644873442.
# [I 2025-03-11 02:27:20,804] Trial 13 finished with value: 2.2619884047657663 and parameters: {'n_estimators': 370, 'max_depth': 11, 'learning_rate': 0.02119005296838839, 'subsample': 0.9386790695277416, 'colsample_bytree': 0.8547520028374415}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:21,469] Trial 14 finished with value: 2.2675307694597056 and parameters: {'n_estimators': 371, 'max_depth': 11, 'learning_rate': 0.024173871584214003, 'subsample': 0.9378411651863958, 'colsample_bytree': 0.9006651281827351}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:21,668] Trial 15 finished with value: 2.281638705506551 and parameters: {'n_estimators': 271, 'max_depth': 8, 'learning_rate': 0.09454043868964507, 'subsample': 0.948801797309615, 'colsample_bytree': 0.9060824556074581}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:22,259] Trial 16 finished with value: 2.2793012201686564 and parameters: {'n_estimators': 390, 'max_depth': 11, 'learning_rate': 0.030769797273929953, 'subsample': 0.7881074990537696, 'colsample_bytree': 0.9979357919146328}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:22,463] Trial 17 finished with value: 2.2880978828682093 and parameters: {'n_estimators': 329, 'max_depth': 5, 'learning_rate': 0.019423758262555428, 'subsample': 0.9976812959132392, 'colsample_bytree': 0.7875730750456228}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:22,886] Trial 18 finished with value: 2.3146263018426594 and parameters: {'n_estimators': 281, 'max_depth': 9, 'learning_rate': 0.011987901270302576, 'subsample': 0.8186511278449585, 'colsample_bytree': 0.8515562009703334}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:23,540] Trial 19 finished with value: 2.3765483614006224 and parameters: {'n_estimators': 348, 'max_depth': 11, 'learning_rate': 0.005944613709592384, 'subsample': 0.9145654150448436, 'colsample_bytree': 0.9401249269338694}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:23,660] Trial 20 finished with value: 2.3698350373234423 and parameters: {'n_estimators': 139, 'max_depth': 6, 'learning_rate': 0.020934773868011673, 'subsample': 0.61074688596406, 'colsample_bytree': 0.8345009106511949}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:24,903] Trial 21 finished with value: 2.276748720251685 and parameters: {'n_estimators': 492, 'max_depth': 12, 'learning_rate': 0.013430305212682635, 'subsample': 0.9494088902584819, 'colsample_bytree': 0.8439124724889527}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:26,121] Trial 22 finished with value: 2.3622812476349004 and parameters: {'n_estimators': 442, 'max_depth': 15, 'learning_rate': 0.005161248227825895, 'subsample': 0.9138873069285216, 'colsample_bytree': 0.7699545104167552}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:26,565] Trial 23 finished with value: 2.2631849763829273 and parameters: {'n_estimators': 400, 'max_depth': 9, 'learning_rate': 0.03154290294730416, 'subsample': 0.9670812007306472, 'colsample_bytree': 0.8613922551400857}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:27,062] Trial 24 finished with value: 2.2658410000819775 and parameters: {'n_estimators': 403, 'max_depth': 9, 'learning_rate': 0.027852765224826555, 'subsample': 0.9499166047161799, 'colsample_bytree': 0.8767867540847724}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:27,492] Trial 25 finished with value: 2.2708833253862033 and parameters: {'n_estimators': 396, 'max_depth': 8, 'learning_rate': 0.031929809058895184, 'subsample': 0.8970025371924779, 'colsample_bytree': 0.8722667848188861}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:27,913] Trial 26 finished with value: 2.266178160192017 and parameters: {'n_estimators': 416, 'max_depth': 9, 'learning_rate': 0.03553973466234329, 'subsample': 0.8449619271505187, 'colsample_bytree': 0.7517600256791412}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:28,353] Trial 27 finished with value: 2.2889846415965227 and parameters: {'n_estimators': 385, 'max_depth': 8, 'learning_rate': 0.02605345078129538, 'subsample': 0.7699183658867068, 'colsample_bytree': 0.806512184321761}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:28,853] Trial 28 finished with value: 2.267846144649989 and parameters: {'n_estimators': 306, 'max_depth': 12, 'learning_rate': 0.03888462038612515, 'subsample': 0.9561434346824611, 'colsample_bytree': 0.8995325314503473}. Best is trial 13 with value: 2.2619884047657663.
# [I 2025-03-11 02:27:29,312] Trial 29 finished with value: 2.2754503208340977 and parameters: {'n_estimators': 416, 'max_depth': 7, 'learning_rate': 0.02023445859426739, 'subsample': 0.9263735803430133, 'colsample_bytree': 0.8653128520367392}. Best is trial 13 with value: 2.2619884047657663.
# Best parameters for XRP-USD: {'n_estimators': 370, 'max_depth': 11, 'learning_rate': 0.02119005296838839, 'subsample': 0.9386790695277416, 'colsample_bytree': 0.8547520028374415}
# XGBoost Results for XRP-USD:
# MSE: 2.27
# MAPE: 52.13%
# Directional Accuracy: 50.00%
# Feature Open: 0.0138
# Feature High: 0.1860
# Feature Low: 0.0202
# Feature Close: 0.7046
# Feature Volume: 0.0041
# Feature Lag1: 0.0232
# Feature Lag7: 0.0056
# Feature SMA7: 0.0137
# Feature RSI14: 0.0088
# Feature MACD: 0.0067
# Feature Returns: 0.0036
# Feature Volatility: 0.0098
# Model and scaler saved for XRP-USD
